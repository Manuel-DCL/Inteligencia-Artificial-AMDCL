# %% [markdown]
# <a href="https://colab.research.google.com/github/Manuel-DCL/Inteligencia-Artificial-AMDCL/blob/main/Examen_Entrenamiento_de_redes_neuronales_TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#paso 1
# !pip install tensorflowjs

#paso 2
# !pip install tensorflow==2.16.0rc0

#paso 3
import os
os.environ['TF_USE_LEGACY_KERAS'] = "1"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 86.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 89.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 53.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 63.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
# ...

# %%
# !rm -rf Tendencia
#Paso 4
# !mkdir Tendencia

#Paso 5
import tensorflow as tf
import numpy as np


datos_ventas = np.array([
    # Año 1
    [381, 2129, 1953, 4217, 1807, 2497, 4054, 616, 852, 4602, 2215, 4705],  # Jabón
    [4187, 1466, 1372, 1688, 4004, 148, 2609, 4611, 1661, 4766, 1213, 1775],  # Shampoo
    [1101, 2819, 523, 163, 3100, 4168, 2535, 2016, 1109, 1846, 1491, 1492],  # Esponja
    [955, 3330, 79, 4412, 745, 2115, 4951, 869, 4517, 1263, 2132, 678],  # Acondicionador
    [1920, 4049, 1991, 2631, 4236, 3983, 1238, 4915, 4354, 1519, 3009, 2984],  # Moose
    [520, 4612, 3720, 4838, 2042, 1608, 142, 3287, 3024, 3740, 4278, 976],  # Crema
    [3429, 2442, 3660, 644, 2844, 1717, 18, 4247, 4269, 3698, 351, 4084],  # Papas
    [3448, 4816, 2817, 917, 2494, 740, 4002, 2363, 4785, 2109, 3793, 3698],  # Coca
    [1002, 837, 1120, 1488, 4973, 847, 2761, 4536, 2989, 721, 4067, 1458],  # Cereal
    [2639, 1813, 2068, 238, 2423, 758, 1573, 2068, 1560, 1223, 4410, 4942],  # Fabuloso

    # Año 2
    [1247, 1295, 4901, 2161, 4558, 299, 1315, 2004, 2909, 4653, 2628, 2059],  # Jabón
    [4886, 2709, 3868, 805, 468, 2163, 1392, 4237, 130, 1463, 4751, 3442],  # Shampoo
    [2306, 322, 164, 1818, 1086, 3592, 3373, 1977, 2001, 196, 1584, 2383],  # Esponja
    [4910, 3060, 1424, 3108, 3710, 2682, 1510, 2402, 1863, 4264, 3230, 1572],  # Acondicionador
    [2891, 2993, 4673, 1060, 2345, 3750, 4166, 2179, 4522, 2575, 1681, 971],  # Moose
    [4988, 591, 903, 2063, 3962, 2641, 338, 381, 990, 4870, 2096, 1295],  # Crema
    [2783, 2530, 845, 3867, 2926, 4726, 3568, 339, 364, 2381, 591, 2758],  # Papas
    [639, 2289, 3537, 3370, 3903, 3517, 3200, 4767, 580, 1692, 2891, 316],  # Coca
    [2507, 53, 3558, 2037, 806, 647, 3507, 5000, 3963, 269, 2237, 4256],  # Cereal
    [933, 2461, 2018, 1542, 4886, 2906, 2444, 2243, 2173, 2945, 1950, 1871],  # Fabuloso

    # Año 3
    [354, 2723, 2181, 2575, 2618, 4042, 2504, 2417, 1164, 3499, 3228, 3453],  # Jabón
    [1963, 1371, 486, 3828, 1688, 3572, 2921, 2776, 4209, 4960, 1751, 2964],  # Shampoo
    [747, 399, 554, 1464, 3246, 2118, 149, 2894, 4054, 3432, 1743, 4398],  # Esponja
    [4503, 657, 625, 4642, 3045, 2982, 4902, 1616, 2641, 2365, 2769, 1618],  # Acondicionador
    [4558, 1267, 1104, 3016, 1871, 1276, 4629, 788, 4628, 533, 281, 2472],  # Moose
    [1859, 828, 1907, 2718, 911, 1106, 96, 2330, 46, 1384, 551, 4309],  # Crema
    [4092, 1180, 4428, 3730, 4803, 402, 3559, 1752, 1329, 3387, 3073, 2018],  # Papas
    [1894, 680, 1883, 186, 4465, 2884, 931, 464, 1528, 4060, 4928, 1918],  # Coca
    [1924, 3721, 3455, 1686, 635, 3752, 1731, 2112, 3432, 570, 4423, 2361],  # Cereal
    [3819, 4779, 3007, 2547, 3399, 3914, 2290, 284, 1460, 3086, 3529, 4254],  # Fabuloso

    # Año 4
    [3786, 2652, 224, 39, 187, 3178, 2554, 1757, 2261, 3741, 58, 3785],  # Jabón
    [2209, 3481, 4894, 8, 4776, 2620, 2700, 4602, 297, 2806, 896, 588],  # Shampoo
    [1657, 750, 4834, 363, 4389, 2970, 4777, 1697, 2008, 3214, 4775, 2646],  # Esponja
    [4554, 2437, 1802, 977, 4251, 2487, 1769, 4229, 2257, 2373, 2100, 2268],  # Acondicionador
    [549, 4871, 3284, 1155, 3149, 4685, 3493, 3171, 3728, 3716, 2349, 617],  # Moose
    [285, 1473, 782, 110, 4502, 3036, 4795, 4107, 1192, 4914, 1781, 1139],  # Crema
    [3291, 3152, 1678, 3351, 4359, 4142, 2621, 312, 1763, 2297, 2261, 843],  # Papas
    [362, 1607, 4218, 1705, 2363, 1853, 4097, 1642, 3431, 3030, 3319, 2906],  # Coca
    [161, 4980, 1655, 2545, 4985, 4528, 2898, 3280, 2948, 1628, 4654, 1778],  # Cereal
    [2291, 4906, 2054, 2321, 3179, 2210, 3879, 4065, 3257, 1012, 365, 4871],  # Fabuloso

    # Año 5
    [3422, 489, 4444, 4129, 2645, 3455, 474, 2744, 1318, 3723, 494, 4886],  # Jabón
    [111, 3335, 3833, 2731, 1385, 353, 3324, 1757, 4586, 152, 4433, 2476],  # Shampoo
    [340, 3606, 3255, 4982, 2846, 1719, 1381, 3359, 334, 64, 374, 2022],  # Esponja
    [2443, 240, 3133, 1844, 3665, 3686, 4495, 4245, 4187, 4482, 4285, 3558],  # Acondicionador
    [2412, 1005, 3839, 2746, 1918, 2201, 4234, 3682, 2108, 2265, 3398, 678],  # Moose
    [1073, 78, 1515, 1227, 1436, 2487, 3664, 2800, 2959, 3883, 1576, 1485],  # Crema
    [2603, 2488, 4806, 1406, 2914, 2295, 2696, 1566, 2988, 80, 4553, 1939],  # Papas
    [4912, 291, 1956, 3656, 493, 3955, 2654, 1261, 2498, 2266, 149, 2626],  # Coca
    [1163, 4342, 232, 2565, 1789, 1095, 4441, 1577, 4374, 3753, 3771, 1527],  # Cereal
    [1104, 1908, 646, 1071, 4018, 3537, 4539, 4975, 4736, 2330, 4088, 4615]  # Fabuloso
])


# Reestructuración de datos de ventas para cada producto y año
X = []
y = []


total_meses = datos_ventas.shape[0] * datos_ventas.shape[1]  # Calculamos el total de meses
print(total_meses)
meses_por_anio = 12  # Suponiendo que cada fila tiene 12 meses de ventas
anios_totales = 5  # Suponiendo que tenemos 5 años de datos
anios_entrenamiento = 4  # Entrenamiento de 4 años
anios_prediccion = 1  # Predicción de 1 año

# Determinar la cantidad de productos en el conjunto de datos
num_productos = datos_ventas.shape[0]

# Crear los datos de entrenamiento y objetivo para cada producto
for i in range(num_productos):
    start_col = i * meses_por_anio
    end_col = (i + 1) * meses_por_anio
    if end_col > datos_ventas.shape[1]:
        break  # Evitar el desbordamiento de índice
    producto_data = datos_ventas[:, start_col:end_col]

    print("Dimensiones de producto_data para producto", i, ":", producto_data.shape)

    for j in range(anios_totales - anios_entrenamiento - anios_prediccion + 1):
        X.append(producto_data[j:j + anios_entrenamiento].flatten())
        y.append(producto_data[j + anios_entrenamiento:j + anios_entrenamiento + anios_prediccion].flatten())

# Convertimos X e y a numpy arrays
X = np.array(X)
y = np.array(y)

print("Forma de X:", X.shape)
print("Forma de y:", y.shape)


# Verificamos la forma de X e y
print("Forma de X:", X.shape)
print("Forma de y:", y.shape)

# Definición del modelo
modelo = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(48,)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(12)  # Capa de salida para cada mes de ventas
])

# Compilación del modelo
modelo.compile(optimizer='adam', loss='mean_squared_error')

# Entrenamiento del modelo
historial = modelo.fit(X, y, epochs=300, verbose=False)
print("Modelo entrenado")

# Guardado del modelo en formato para TensorFlow.js
modelo.save('modelo_ventas.h5')
# !tensorflowjs_converter --input_format keras modelo_ventas.h5 Tendencia
# Out:
# 600
# Dimensiones de producto_data para producto 0 : (50, 12)
# Forma de X: (1, 48)
# Forma de y: (1, 12)
# Forma de X: (1, 48)
# Forma de y: (1, 12)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-a5016dede90b> in <cell line: 126>()
#     124
#     125 # Entrenamiento del modelo
# --> 126 historial = modelo.fit(X, y, epochs=300, verbose=False)
#     127 print("Modelo entrenado")
#     128
#
# /usr/local/lib/python3.10/dist-packages/tf_keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ...

# %% [markdown]
# # Modelo de recomendación

# %%
# !rm -r recomendacion
# Paso 4
# !mkdir recomendacion

#Paso 5
import tensorflow as tf
import numpy as np

calificaciones = np.array([
    #Jabón, Shampoo, Esponja, Acondicionador, Moose, Crema, Papas, Coca, Cereal, Fabuloso
    [1, 1, 4, 5, 2, 3, 1, 1, 1, 2],  # Usuario 1
    [1, 5, 1, 3, 2, 3, 2, 1, 4, 5],  # Usuario 2
    [4, 3, 2, 1, 4, 3, 0, 4, 4, 5],  # Usuario 3
    [3, 4, 4, 4, 4, 3, 2, 5, 4, 3],  # Usuario 4
    [4, 3, 5, 0, 1, 3, 5, 2, 5, 2],  # Usuario 5
    [5, 2, 1, 4, 2, 4, 4, 4, 4, 2],  # Usuario 6
    [3, 4, 4, 4, 4, 3, 0, 5, 4, 3],  # Usuario 7
    [4, 3, 5, 1, 1, 3, 5, 2, 5, 2],  # Usuario 8
    [5, 2, 1, 4, 2, 4, 4, 4, 4, 2],  # Usuario 9
    [5, 3, 0, 1, 4, 0, 0, 2, 5, 2]   # Usuario 10
])

# Definición del modelo
modelo = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(10,)),  # Entrada de 10 características
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)  # Salida de 10 calificaciones
])

# Compilación del modelo
modelo.compile(optimizer='adam', loss='mean_squared_error')

# Entrenamiento del modelo
historial = modelo.fit(calificaciones, calificaciones, epochs=500, verbose=False)
print("Modelo entrenado!")

# Guardar el modelo
modelo.save('modelo_recomendacion.h5')

# Convertir a TensorFlow.js
# !tensorflowjs_converter --input_format keras modelo_recomendacion.h5 recomendacion
# Out:
# Modelo entrenado!
# /usr/local/lib/python3.10/dist-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2024-10-28 00:02:35.581960: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:root:TensorFlow Decision Forests 1.10.0 is compatible with the following TensorFlow Versions: ['2.17.0']. However, TensorFlow 2.16.0-rc0 was detected. This can cause issues with the TF API and symbols in the custom C++ ops. See the TF and TF-DF compatibility table at https://github.com/tensorflow/decision-forests/blob/main/documentation/known_issues.md#compatibility-table.
